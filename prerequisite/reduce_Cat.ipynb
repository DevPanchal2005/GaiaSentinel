# %%
import os
from pathlib import Path
import shutil

# Configuration
label_dir = Path("data/new_labels")  
image_dir = Path("data/images")  

# Keep only these old classes and remap them to new ones
old_to_new = {
    15: 0,
    27: 1,
    26: 2,
    3: 3,
    4: 4,
    12: 5,
    6: 6,
    7: 7,
    8: 8,
    24: 9,
    13: 10,
    5: 11,
    25: 12,
    19: 13
}

def clean_labels():
    label_path = label_dir 
    image_path = image_dir 

    for label_file in label_path.glob("*.txt"):
        with open(label_file, 'r') as f:
            lines = f.readlines()

        new_lines = []
        for line in lines:
            parts = line.strip().split()
            if len(parts) < 5:
                print(f"Invalid line in {label_file}: {line}")
                continue
            class_id = int(parts[0])
            if class_id in old_to_new:
                parts[0] = str(old_to_new[class_id])
                new_lines.append(" ".join(parts))

        if new_lines:
            with open(label_file, 'w') as f:
                f.write("\n".join(new_lines))
        else:
            # No valid annotations — remove label and image
            print(f"Removing {label_file} (no valid annotations)")
            label_file.unlink()
            img_path = image_path / (label_file.stem + ".jpg")
            if img_path.exists():
                print(f"Removing {img_path}")
                img_path.unlink()
            else:
                # check for png or jpeg
                for ext in ['.png', '.jpeg']:
                    alt_img = image_path / (label_file.stem + ext)
                    if alt_img.exists():
                        print(f"Removing {alt_img}")
                        alt_img.unlink()
                        break
    print("Label cleaning complete.")


clean_labels()
# Out:
# Removing data\new_labels\batch_10_000018.txt (no valid annotations)
# Removing data\images\batch_10_000018.jpg
# Removing data\new_labels\batch_10_000024.txt (no valid annotations)
# Removing data\images\batch_10_000024.jpg
# Removing data\new_labels\batch_10_000061.txt (no valid annotations)
# Removing data\images\batch_10_000061.jpg
# Removing data\new_labels\batch_10_000069.txt (no valid annotations)
# Removing data\images\batch_10_000069.jpg
# Removing data\new_labels\batch_11_000020.txt (no valid annotations)
# Removing data\images\batch_11_000020.jpg
# Removing data\new_labels\batch_11_000022.txt (no valid annotations)
# Removing data\images\batch_11_000022.jpg
# Removing data\new_labels\batch_11_000025.txt (no valid annotations)
# Removing data\images\batch_11_000025.jpg
# Removing data\new_labels\batch_11_000027.txt (no valid annotations)
# Removing data\images\batch_11_000027.jpg
# Removing data\new_labels\batch_12_000016.txt (no valid annotations)
# Removing data\images\batch_12_000016.jpg
# Removing data\new_labels\batch_12_000036.txt (no valid annotations)
# Removing data\images\batch_12_000036.jpg
# Removing data\new_labels\batch_13_000001.txt (no valid annotations)
# Removing data\images\batch_13_000001.jpg
# Removing data\new_labels\batch_13_000030.txt (no valid annotations)
# Removing data\images\batch_13_000030.jpg
# Removing data\new_labels\batch_13_000032.txt (no valid annotations)
# Removing data\images\batch_13_000032.jpg
# Removing data\new_labels\batch_13_000033.txt (no valid annotations)
# Removing data\images\batch_13_000033.jpg
# Removing data\new_labels\batch_13_000055.txt (no valid annotations)
# Removing data\images\batch_13_000055.jpg
# Removing data\new_labels\batch_13_000060.txt (no valid annotations)
# Removing data\images\batch_13_000060.jpg
# Removing data\new_labels\batch_13_000062.txt (no valid annotations)
# Removing data\images\batch_13_000062.jpg
# Removing data\new_labels\batch_13_000064.txt (no valid annotations)
# Removing data\images\batch_13_000064.jpg
# Removing data\new_labels\batch_13_000091.txt (no valid annotations)
# Removing data\images\batch_13_000091.jpg
# Removing data\new_labels\batch_13_000098.txt (no valid annotations)
# Removing data\images\batch_13_000098.jpg
# Removing data\new_labels\batch_14_000055.txt (no valid annotations)
# Removing data\images\batch_14_000055.jpg
# Removing data\new_labels\batch_15_000014.txt (no valid annotations)
# Removing data\images\batch_15_000014.jpg
# Removing data\new_labels\batch_15_000027.txt (no valid annotations)
# Removing data\images\batch_15_000027.jpg
# Removing data\new_labels\batch_15_000033.txt (no valid annotations)
# Removing data\images\batch_15_000033.jpg
# Removing data\new_labels\batch_15_000034.txt (no valid annotations)
# Removing data\images\batch_15_000034.jpg
# Removing data\new_labels\batch_15_000061.txt (no valid annotations)
# Removing data\images\batch_15_000061.jpg
# Removing data\new_labels\batch_1_000078.txt (no valid annotations)
# Removing data\images\batch_1_000078.jpg
# Removing data\new_labels\batch_1_000079.txt (no valid annotations)
# Removing data\images\batch_1_000079.jpg
# Removing data\new_labels\batch_1_000093.txt (no valid annotations)
# Removing data\images\batch_1_000093.jpg
# Removing data\new_labels\batch_1_000119.txt (no valid annotations)
# Removing data\images\batch_1_000119.jpg
# Removing data\new_labels\batch_2_000031.txt (no valid annotations)
# Removing data\images\batch_2_000031.jpg
# Removing data\new_labels\batch_2_000055.txt (no valid annotations)
# Removing data\images\batch_2_000055.jpg
# Removing data\new_labels\batch_2_000077.txt (no valid annotations)
# Removing data\images\batch_2_000077.jpg
# Removing data\new_labels\batch_3_IMG_4879.txt (no valid annotations)
# Removing data\images\batch_3_IMG_4879.jpg
# Removing data\new_labels\batch_3_IMG_4907.txt (no valid annotations)
# Removing data\images\batch_3_IMG_4907.jpg
# Removing data\new_labels\batch_3_IMG_4916.txt (no valid annotations)
# Removing data\images\batch_3_IMG_4916.jpg
# Removing data\new_labels\batch_3_IMG_4926.txt (no valid annotations)
# Removing data\images\batch_3_IMG_4926.jpg
# Removing data\new_labels\batch_3_IMG_4961.txt (no valid annotations)
# Removing data\images\batch_3_IMG_4961.jpg
# Removing data\new_labels\batch_4_000037.txt (no valid annotations)
# Removing data\images\batch_4_000037.jpg
# Removing data\new_labels\batch_4_000041.txt (no valid annotations)
# Removing data\images\batch_4_000041.jpg
# Removing data\new_labels\batch_4_000046.txt (no valid annotations)
# Removing data\images\batch_4_000046.jpg
# Removing data\new_labels\batch_4_000047.txt (no valid annotations)
# Removing data\images\batch_4_000047.jpg
# Removing data\new_labels\batch_4_000050.txt (no valid annotations)
# Removing data\images\batch_4_000050.jpg
# Removing data\new_labels\batch_4_000051.txt (no valid annotations)
# Removing data\images\batch_4_000051.jpg
# Removing data\new_labels\batch_4_000055.txt (no valid annotations)
# Removing data\images\batch_4_000055.jpg
# Removing data\new_labels\batch_4_000064.txt (no valid annotations)
# Removing data\images\batch_4_000064.jpg
# Removing data\new_labels\batch_4_000086.txt (no valid annotations)
# Removing data\images\batch_4_000086.jpg
# Removing data\new_labels\batch_5_000018.txt (no valid annotations)
# Removing data\images\batch_5_000018.jpg
# Removing data\new_labels\batch_5_000024.txt (no valid annotations)
# Removing data\images\batch_5_000024.jpg
# Removing data\new_labels\batch_5_000039.txt (no valid annotations)
# Removing data\images\batch_5_000039.jpg
# Removing data\new_labels\batch_5_000054.txt (no valid annotations)
# Removing data\images\batch_5_000054.jpg
# Removing data\new_labels\batch_5_000075.txt (no valid annotations)
# Removing data\images\batch_5_000075.jpg
# Removing data\new_labels\batch_5_000081.txt (no valid annotations)
# Removing data\images\batch_5_000081.jpg
# Removing data\new_labels\batch_5_000087.txt (no valid annotations)
# Removing data\images\batch_5_000087.jpg
# Removing data\new_labels\batch_5_000098.txt (no valid annotations)
# Removing data\images\batch_5_000098.jpg
# Removing data\new_labels\batch_6_000011.txt (no valid annotations)
# Removing data\images\batch_6_000011.jpg
# Removing data\new_labels\batch_6_000018.txt (no valid annotations)
# Removing data\images\batch_6_000018.jpg
# Removing data\new_labels\batch_6_000022.txt (no valid annotations)
# Removing data\images\batch_6_000022.jpg
# Removing data\new_labels\batch_6_000035.txt (no valid annotations)
# Removing data\images\batch_6_000035.jpg
# Removing data\new_labels\batch_6_000039.txt (no valid annotations)
# Removing data\images\batch_6_000039.jpg
# Removing data\new_labels\batch_6_000041.txt (no valid annotations)
# Removing data\images\batch_6_000041.jpg
# Removing data\new_labels\batch_6_000048.txt (no valid annotations)
# Removing data\images\batch_6_000048.jpg
# Removing data\new_labels\batch_6_000053.txt (no valid annotations)
# Removing data\images\batch_6_000053.jpg
# Removing data\new_labels\batch_6_000063.txt (no valid annotations)
# Removing data\images\batch_6_000063.jpg
# Removing data\new_labels\batch_6_000070.txt (no valid annotations)
# Removing data\images\batch_6_000070.jpg
# Removing data\new_labels\batch_6_000079.txt (no valid annotations)
# Removing data\images\batch_6_000079.jpg
# Removing data\new_labels\batch_6_000086.txt (no valid annotations)
# Removing data\images\batch_6_000086.jpg
# Removing data\new_labels\batch_6_000088.txt (no valid annotations)
# Removing data\images\batch_6_000088.jpg
# Removing data\new_labels\batch_6_000089.txt (no valid annotations)
# Removing data\images\batch_6_000089.jpg
# Removing data\new_labels\batch_6_000091.txt (no valid annotations)
# Removing data\images\batch_6_000091.jpg
# Removing data\new_labels\batch_6_000098.txt (no valid annotations)
# Removing data\images\batch_6_000098.jpg
# Removing data\new_labels\batch_7_000008.txt (no valid annotations)
# Removing data\images\batch_7_000008.jpg
# Removing data\new_labels\batch_7_000014.txt (no valid annotations)
# Removing data\images\batch_7_000014.jpg
# Removing data\new_labels\batch_7_000019.txt (no valid annotations)
# Removing data\images\batch_7_000019.jpg
# Removing data\new_labels\batch_7_000056.txt (no valid annotations)
# Removing data\images\batch_7_000056.jpg
# Removing data\new_labels\batch_8_000001.txt (no valid annotations)
# Removing data\images\batch_8_000001.jpg
# Removing data\new_labels\batch_8_000082.txt (no valid annotations)
# Removing data\images\batch_8_000082.jpg
# Removing data\new_labels\batch_8_000099.txt (no valid annotations)
# Removing data\images\batch_8_000099.jpg
# Removing data\new_labels\batch_9_000019.txt (no valid annotations)
# Removing data\images\batch_9_000019.jpg
# Removing data\new_labels\batch_9_000033.txt (no valid annotations)
# Removing data\images\batch_9_000033.jpg
# Label cleaning complete.
